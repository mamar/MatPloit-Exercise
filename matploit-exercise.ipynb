# %% [markdown]
# <a href="https://www.kaggle.com/code/mamarhabtamu/matploit-exercise?scriptVersionId=172873322" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoint= np.array([0,6])

# %%
ypoint=np.array([0,250])

# %%
plt.plot(xpoint,ypoint)

# %%
a=np.array([1,6])

# %%
b=np.array([3, 10])

# %%
plt.plot(a,b)

# %%
c=np.array([1,3])
d=np.array([3,10])
plt.plot(c,d,'o')

# %%
f=np.array([1,2,6,8])

# %%
g=np.array([3,8,1,10])
plt.plot(f,g,'')

# %%
plt.plot(f,g,'o')

# %%
k=np.array([10,2,6,7,9,8,2,20])

# %%
plt.plot(k)

# %%
plt.plot(k,marker='*')

# %%
plt.plot(k,marker='x')

# %%
plt.plot(k,marker='D')

# %%
plt.plot(k,marker='3')

# %%
plt.plot(k,marker='3')

# %%
plt.plot(k,marker='P')

# %%
plt.plot(k,'o:r')

# %%
plt.plot(k,'o:b')

# %%
plt.plot(k,'v:r')

# %%
plt.plot(k,'o--')

# %%
plt.plot(k,'o:m')

# %%
plt.plot(k,'o:c')

# %%
plt.plot(k,'o:c' ,ms=10)

# %%
plt.plot(k,marker='o',ms=10,mec='r')

# %%
plt.plot(k,marker='o',ms=15,mfc='r')

# %%
plt.plot(k,marker='o',ms=15,mec='r',mfc='#4CAF50')

# %%
plt.plot(k,linestyle='dotted')

# %%
plt.plot(k,ls='dashed')

# %%
plt.plot(k,ls=':')

# %%
plt.plot(k,ls='solid')

# %%
plt.plot(k,ls='None')

# %%
plt.plot(k,ls='dashdot')

# %%
plt.plot(k,ls='dashdot',color='c')

# %%
plt.plot(k,marker= 'o',ls='dashed',c='r')

# %%
plt.plot(k,lw=2,c='c',marker='o',ms='10',ls='dashdot',mfc='r')

# %%
m=np.array([10,3,5,1,7,2,10,15,1])

# %%
plt.plot(k,lw=1,c='r',ls='solid',marker='h',mfc='c',ms=10)
plt.plot(m,lw=1,c='c',ls='dashdot',marker='h',mfc='c',ms=10)

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.plot(x,y)
plt.xlabel(xlabel="Average Plus",fontdict=font1)
plt.ylabel("Calory plus",fontdict=font2)
plt.title("Sports Watch Data",fontdict=font1,loc='center')
# Out:
# Text(0.5, 1.0, 'Sports Watch Data')

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.plot(x,y)
plt.xlabel(xlabel="Average Plus",fontdict=font1)
plt.ylabel("Calory plus",fontdict=font2)
plt.title("Sports Watch Data",fontdict=font1,loc='center')
plt.grid(axis='x')
plt.grid(axis='y',ls='--',lw=0.5,c='r')

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y,c='pink')
#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y,color='c')

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes,alpha=0.8)

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

# %%
name=np.array(['Mamar','Jafar','Fikadu','Biruk'])
age=np.array([1,10,6,3])
plt.bar(x,y)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.xlabel("Name",fontdict=font1)
plt.ylabel("Age",fontdict=font2)
plt.title("Name with Age",loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'Name with Age')

# %%
name=np.array(['Mamar','Jafar','Fikadu','Biruk'])
age=np.array([1,10,6,3])
plt.barh(x,y)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.xlabel("Name",fontdict=font1)
plt.ylabel("Age",fontdict=font2)
plt.title("Name with Age",loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'Name with Age')

# %%
name=np.array(['Mamar','Jafar','Fikadu','Biruk'])
age=np.array([1,10,6,3])
plt.bar(x,y,color='red',width=0.1)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.xlabel("Name",fontdict=font1)
plt.ylabel("Age",fontdict=font2)
plt.title("Name with Age",loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'Name with Age')

# %%
name=np.array(['Mamar','Jafar','Fikadu','Biruk'])
age=np.array([1,10,6,3])
plt.barh(x,y,color='red',height=0.5)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.xlabel("Name",fontdict=font1)
plt.ylabel("Age",fontdict=font2)
plt.title("Name with Age",loc='center',color='r')
# Out:
# Text(0.5, 1.0, 'Name with Age')

# %%
x=np.array([25,42,25,75,75,68,90,49])
Fruits=['Banana','orange','Banana','potato','potato','ananace','beef','meet']

# %%
plt.pie(x,labels=Fruits)
plt.legend()
plt.title("Repitions of number",color='c')
# Out:
# Text(0.5, 1.0, 'Repitions of number')

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c402d522ec0>,
# ...
#  [Text(0.5901876713511442, 1.1583084703934068, 'Apples'),
#   Text(-1.086457168210212, 0.17207795223283895, 'Bananas'),
#   Text(-0.172077952232839, -1.086457168210212, 'Cherries'),
#   Text(0.9801071672559598, -0.4993895680663526, 'Dates')])
